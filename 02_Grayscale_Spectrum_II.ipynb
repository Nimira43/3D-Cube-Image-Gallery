# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimira43/3D-Cube-Image-Gallery/blob/main/02_Grayscale_Spectrum_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Reading, Manipulating and Saving Grayscale Image

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %% [markdown]
# ### Processing Grayscale Images

# %% [markdown]
# #### Image of Albert Einstein

# %%
einstein = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/albert-einstein_gray.jpg')

# %%
einstein.shape
# Out:
# (949, 728)

# %%
type(einstein)
# Out:
# numpy.ndarray

# %%
einstein.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(einstein, cmap='gray')

# %% [markdown]
# #### Image of Jack Brabham

# %%
brabham = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/brabham.jpg')

# %%
brabham.shape
# Out:
# (641, 1140, 3)

# %%
type(brabham)
# Out:
# numpy.ndarray

# %%
brabham.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(brabham, cmap='gray')

# %% [markdown]
# #### Image of Bruce McLaren

# %%
mclaren = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/mclaren.jpg')

# %%
mclaren.shape
# Out:
# (450, 338, 3)

# %%
plt.imshow(mclaren, cmap='gray')

# %% [markdown]
# #### Image of Stirling Moss

# %%
moss = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/moss.jpg')

# %%
moss.shape
# Out:
# (500, 400, 3)

# %%
plt.imshow(moss, cmap='gray')

# %% [markdown]
# #### Image of Alberto Ascari

# %%
ascari = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/ascari.jpg')

# %%
ascari.shape
# Out:
# (394, 634, 3)

# %%
plt.imshow(ascari, cmap='gray')

# %% [markdown]
# ### Image of Juan Manuel Fangio

# %%
fangio = plt.imread(r'/content/drive/MyDrive/Colab Notebooks/Computer-Vision/fangio.jpg')

# %%
fangio.shape
# Out:
# (400, 400)

# %%
plt.imshow(fangio, cmap='gray')
